# %%
import pandas as pd

DATA_PATH = '../data/'
filename  = 'fbget_sample_05.csv'

df = pd.read_csv(DATA_PATH + filename)
# df = df[0:1000]

# sampler 

df = df.sample(frac= 0.5)
df.reset_index(inplace = True, drop = True)
print(df.shape)

df2=df["message_clean"]


df2

# Tokenization
from nltk import word_tokenize

# La phrase
sentence = "les médiateurs confirment « l'absence de solution parfaite ». "

tokens = word_tokenize(sentence)

print(tokens)
tokens_on_space = sentence.split(' ')
print(tokens_on_space)



# ponctuation

import string

print("Liste original de signe de ponctuations")
print("\t{}".format(string.punctuation))

sentence = "les médiateurs confirment « l'absence de solution parfaite ». "
punctuation_chars = string.punctuation + "«»"

#  Construction d'un dict { '~':' ', '$': ' ', ... }
dict_ponctuation = {}
for k in punctuation_chars:
    dict_ponctuation[k] = ' '

print(dict_ponctuation)

# # L'operateur de translation
translator = str.maketrans(dict_ponctuation)

new_sentence = sentence.translate(translator)
print(sentence)
print(new_sentence)



# stopwords
tokens = word_tokenize(new_sentence)
print(tokens)

from nltk.corpus import stopwords


# print("=== stopwords - français:")
# print(sorted(stopwords.words('french')))

list_stopwords = stopwords.words('english') + ['les', 'de']

# # equivalent:
# stopwords = stopwords.words('french')
# stopwords.append('les')
# stopwords.append('de')


# 
tokens_sans_stopwords = [w for w in tokens if (w not in list_stopwords) ]

## Equivalent 
tokens_sans_stopwords = []
for w in tokens:
    if w not in list_stopwords:
        tokens_sans_stopwords.append(w)



print(tokens_sans_stopwords)



# Enlevons la ponctuation

df2['text_no_punctuation'] = df2.message_clean.apply(lambda 
    r : ( r.translate(translator) ) 
)
df2.head()




# Tokenizer

df2['tokens_all']  = df2.text_no_punctuation.apply(
    lambda r : word_tokenize(r.lower())
)

df2.head()




# remove stopwords

def remove_stopword(tokens):
     return [w for w in tokens if (w not in list_stopwords) ]

# Verifier que ca marche
remove_stopword(tokens)

# appliquer a la dataframe

df2['tokens'] = df2.tokens_all.apply(
    lambda tks : remove_stopword(tks) 
)

df2.head()



# enlever les colonnes intermediaires

print(df2.columns)

df2 = df2[['text', 'tokens']]

print(df2.columns)



# nombre de tokens par rangée
pd.options.mode.chained_assignment = None
df2['token_count'] = df2.tokens.apply( lambda r : len(r) )

print(df2.head())

# repartition du nombre de tokens
df2.token_count.describe()



# quel document a 955 tokens?

#condition = (df.token_count == 955)
#print(df[condition].text.values)



# quel index
#print(df[condition].index)

# 
#condition = (df.token_count < 800)
#print(df[condition].shape)



# enlever le paragraphe le plus long

#condition_filtrage = df.token_count < 955
#print(df[condition_filtrage].shape)

#df = df[condition_filtrage]
#print(df[condition_filtrage].shape)

#print(df.token_count.describe())



# Gensim - Vocabulaire

#from gensim import corpora, models
#dictionary  = corpora.Dictionary(df.tokens)
#print(dictionary)



# corpus_gensim

#df['corpus_gensim'] = df.tokens.apply(lambda d : dictionary.doc2bow(d))

#print(df[['text','corpus_gensim']] .head().values)



#corpus_gensim = [c for c in df.corpus_gensim ]


#num_topics= 10

# Le model LDA
#lda = models.LdaModel(corpus_gensim,
#    id2word      = dictionary,
#    num_topics   = num_topics,
#    alpha        = 'asymmetric',
#    eta          = 'auto',
#    passes       = 2,
#    iterations   = 20
#)



#for t in lda.show_topics(num_topics=num_topics, formatted=True, log = False):
#    print("\n=== topic #{}".format(t[0]))
#    print(t[1].replace('*', ': ').replace(' +',', ').replace('"',''))
# Out:
# (3349, 14)
# ['les', 'médiateurs', 'confirment', '«', "l'absence", 'de', 'solution', 'parfaite', '»', '.']
# ['les', 'médiateurs', 'confirment', '«', "l'absence", 'de', 'solution', 'parfaite', '».', '']
# Liste original de signe de ponctuations
# 	!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# {'!': ' ', '"': ' ', '#': ' ', '$': ' ', '%': ' ', '&': ' ', "'": ' ', '(': ' ', ')': ' ', '*': ' ', '+': ' ', ',': ' ', '-': ' ', '.': ' ', '/': ' ', ':': ' ', ';': ' ', '<': ' ', '=': ' ', '>': ' ', '?': ' ', '@': ' ', '[': ' ', '\\': ' ', ']': ' ', '^': ' ', '_': ' ', '`': ' ', '{': ' ', '|': ' ', '}': ' ', '~': ' ', '«': ' ', '»': ' '}
# les médiateurs confirment « l'absence de solution parfaite ».
# les médiateurs confirment   l absence de solution parfaite
# ['les', 'médiateurs', 'confirment', 'l', 'absence', 'de', 'solution', 'parfaite']
# ['médiateurs', 'confirment', 'l', 'absence', 'solution', 'parfaite']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-673ec4b3ef65> in <module>()
#      93 # Enlevons la ponctuation
#      94
# ---> 95 df2['text_no_punctuation'] = df2.message_clean.apply(lambda
#      96     r : ( r.translate(translator) )
#      97 )
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'message_clean'

# %%
# Out:
# (3349, 14)
# 0       Hi all love you all and Dahnald of course even...
# 1       Well that s not true Mr Trump We Americans car...
# 2       Yeah but Alain Soral is an egotestical piece o...
# 3       The girl from what I last heard is going to be...
# 4       I wrote a massive refute to every point you ma...
# 5       lol oh my gosh that s true I didn t really hat...
# 6       Hey James Rolf isn t a cuck And yes thoses are...
# 7       What would you know about freedom if you never...
# 8       Free speech means that the government cannot s...
# 9       I agree Bad choices all around BUT she does ha...
# 10      I live in the town this was drawn over I saw i...
# 11      The Book The experiment military theological S...
# 12      Ha hope you know the Nazis weren t Socialist T...
# 13      After my service I was finally promoted to mem...
# 14      So she couldn t find a job outside of Hollywoo...
# 15      Just so you know more white people are killed ...
# 16      Andrew Jenson i don t remember what year it wa...
# 17      No I hope you re joking It depends on how you ...
# 18      Donald Trump proposed a drug test I do propose...
# 19      Chad Brosef We ve started playing around with ...
# 20      Hey sayied Why Sri Lanka Sucks Now It sucks to...
# 21      I drank like my Viking ancestors from 15 to 45...
# 22      ATTENTION EVERYONE Early voters have reported ...
# 23      Should we be concerned about this level of shi...
# 24      I was at this talk given by a uni professor as...
# 25      Check black on white rape statistics I talk fa...
# 26      There is a difference between white nationalis...
# 27      Johnson doesn t even have a foot hold on this ...
# 28      It s ok if you need a second to reflect on thi...
# 29      Actually the sad thing is the reason most Amer...
#                               ...
# 3319    1 Evolution is not a belief on how life is cre...
# 3320    Bryce Rawers read the room dude these guys did...
# 3321    To start I agree with Trump s message but alwa...
# 3322    I m a staunch supporter or Trump but we have t...
# 3323    Sabastian Ramey she has been publicly EXONERAT...
# 3324    I m sick of people talking about it who haven ...
# 3325    PROBLEMS SHARED IS PROBLEM SOLVD YOUR HRART TO...
# 3326    In June ADL added the echo symbol to the Hate ...
# 3327    Of course it doesn t They re the hero of their...
# 3328    until he wins that is then the knives will tur...
# 3329    The EU is definitely socialist Have you looked...
# 3330    By definition then i guess i m racist as each ...
# 3331    Castro stood against US domination of his coun...
# 3332    Senator Cruz Disqualifies Himself From Running...
# 3333    I don t jump on Russian dick because I care ab...
# 3334    Being a Muslim is not a crime in itself It is ...
# 3335    every middle class is built on the backs of 10...
# 3336    What s sad is he s a disbarred lawyer just lik...
# 3337    They need to go back to how they were during t...
# 3338    Because we know how to clean a gun make our ow...
# 3339    Brutal yet accurate these type of images need ...
# 3340    In Italy we had Berlusconi doing the same thin...
# 3341    Y all want to say Hilary supporters are this a...
# 3342    Adam Osman You may bend to pull his leg back t...
# 3343    Being a Muslim is not a crime in itself It is ...
# 3344    Josh Bromagen what does a white privilege card...
# 3345    I doubt it will be canceled The assembly paddo...
# 3346    If you re going to vote at all Trump is the be...
# 3347    Please don t it s not that I disagree that the...
# 3348    Wikipedia Jewish mass media production How abo...
# Name: message_clean, Length: 3349, dtype: object

# %%
import pandas as pd

DATA_PATH = '../data/'
filename  = 'fbget_sample_05.csv'

df = pd.read_csv(DATA_PATH + filename)
# df = df[0:1000]

# sampler 

df = df.sample(frac= 0.5)
df.reset_index(inplace = True, drop = True)
print(df.shape)

df2=df["message_clean"]


df2

# Tokenization
from nltk import word_tokenize

# La phrase
#sentence = "les médiateurs confirment « l'absence de solution parfaite ». "

tokens = word_tokenize(df2)
# Out:
# (3349, 14)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-542df7e114a4> in <module>()
#      24 #sentence = "les médiateurs confirment « l'absence de solution parfaite ». "
#      25
# ---> 26 tokens = word_tokenize(df2)
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1235         Given a text, returns a list of the sentences in that text.
#    1236         """
# -> 1237         return list(self.sentences_from_text(text, realign_boundaries))
#    1238
#    1239     def debug_decisions(self, text):
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1283         follows the period.
#    1284         """
# -> 1285         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1286
#    1287     def _slices_from_text(self, text):
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1274         if realign_boundaries:
#    1275             slices = self._realign_boundaries(text, slices)
# -> 1276         return [(sl.start, sl.stop) for sl in slices]
#    1277
#    1278     def sentences_from_text(self, text, realign_boundaries=True):
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1274         if realign_boundaries:
#    1275             slices = self._realign_boundaries(text, slices)
# -> 1276         return [(sl.start, sl.stop) for sl in slices]
#    1277
#    1278     def sentences_from_text(self, text, realign_boundaries=True):
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1314         """
#    1315         realign = 0
# -> 1316         for sl1, sl2 in _pair_iter(slices):
#    1317             sl1 = slice(sl1.start + realign, sl1.stop)
#    1318             if not sl2:
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     310     """
#     311     it = iter(it)
# --> 312     prev = next(it)
#     313     for el in it:
#     314         yield (prev, el)
#
# ~/miniconda3/lib/python3.6/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1287     def _slices_from_text(self, text):
#    1288         last_break = 0
# -> 1289         for match in self._lang_vars.period_context_re().finditer(text):
#    1290             context = match.group() + match.group('after_tok')
#    1291             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
