# %%
import pandas as pd



DATA_PATH = ('../data/')

filename  = 'fbget_original_full_data_2016_and_2017.csv'



df = pd.read_csv(DATA_PATH + filename)

# df = df[0:1000]



# sampler 



df = df.sample(frac= 0.5)

df.reset_index(inplace = True, drop = True)

print(df.shape)



df

print("= dimensions")

print(df.shape)

print("= 5 premieres rangés")

print(df.head())

print("= Noms des colonnes")

print(df.columns)
# Out:
# /home/alexis/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,10,11,18,19,23,25,26,27,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (242162, 40)
# = dimensions
# (242162, 40)
# = 5 premieres rangés
#                             post_id parent_id  \
# 0   791373644322801_951483591645138       NaN
# 1  791373644322801_1392928660833960       NaN
# 2   791373644322801_970124319781065       NaN
# 3   791373644322801_961674330626064       NaN
# 4  791373644322801_1022722014521295       NaN
#
#                           comment_id cc_id           from_id        from_name  \
# 0    951483591645138_951829601610537   NaN  1132056003587540    Erick Aghaian
# 1  1392928660833960_1393518717441621   NaN   183084975531129  Jeremy Bushwell
# 2    970124319781065_970952646364899   NaN   304151623283722  Bryton Cherrier
# 3    961674330626064_961683950625102   NaN   799905623506554  Jackson Fifield
# 4  1022722014521295_1022759461184217   NaN      952473269471    Jack Shepherd
#
#                                              message post_type  \
# 0  ??? I love all these references to the space m...   comment
# 1                      P E A C E F U L E A C E F U L   comment
# 2  That photo of Donald's face is so overused, bu...   comment
# 3  Anybody who doesn't worship the almighty Shkre...   comment
# 4                      Taryn Elizabeth now we can go   comment
#
#    is_post_hidden  is_post_published         ...          comment_count  \
# 0             NaN                NaN         ...                    0.0
# 1             NaN                NaN         ...                    0.0
# 2             NaN                NaN         ...                    0.0
# 3             NaN                NaN         ...                    0.0
# 4             NaN                NaN         ...                    0.0
#
#   action event posting_application  tagged_id_list tagged_name_list  \
# 0    NaN   NaN                 NaN             NaN              NaN
# 1    NaN   NaN                 NaN               0              NaN
# 2    NaN   NaN                 NaN             NaN              NaN
# 3    NaN   NaN                 NaN             NaN              NaN
# 4    NaN   NaN                 NaN             NaN              NaN
#
#   tagged_type_list  video_length updated_at           created_at
# 0              NaN           NaN        NaN  2016-08-31 17:03:43
# 1              NaN           NaN        NaN  2017-11-30 13:24:12
# 2              NaN           NaN        NaN  2016-09-23 04:43:42
# 3              NaN           NaN        NaN  2016-09-11 23:02:57
# 4              NaN           NaN        NaN  2016-11-17 04:48:46
#
# [5 rows x 40 columns]
# = Noms des colonnes
# Index(['post_id', 'parent_id', 'comment_id', 'cc_id', 'from_id', 'from_name',
#        'message', 'post_type', 'is_post_hidden', 'is_post_published',
#        'link_caption', 'link_description', 'link_name', 'link_url', 'media_id',
#        'media_thumnail_url', 'media_url', 'page', 'place_city',
#        'place_country', 'place_id', 'place_latitude', 'place_longitude',
#        'place_name', 'place_region', 'place_state', 'place_street',
#        'place_zip', 'reaction_count', 'share_count', 'comment_count', 'action',
#        'event', 'posting_application', 'tagged_id_list', 'tagged_name_list',
#        'tagged_type_list', 'video_length', 'updated_at', 'created_at'],
#       dtype='object')

# %%
import nltk

nltk.download()


from nltk import word_tokenize

import string
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------

# %%
import pandas as pd



DATA_PATH = '/home/emile/Bureau/sprint_socio_num/'

filename  = 'fbget_sample_05.csv'



df = pd.read_csv(DATA_PATH + filename)

# df = df[0:1000]



# sampler





df = df.sample(frac= 0.5)

df.reset_index(inplace = True, drop = True)

print(df.shape)







df

print("= dimensions")

print(df.shape)

print("= 5 premieres rangés")

print(df.head())

print("= Noms des colonnes")

print(df.columns)
