# %%
import spacy

nlp = spacy.load('en')
doc= nlp(u'Apple is looking at buying U.K. startup for $1 billion')

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
import pandas as pd

df = pd.read_csv('../data/fbget_original_full_data_2016_and_2017.csv')
df.dropna(subset = ['message'], inplace = True)
print(df.shape)
# Extraire toutes les orgs et les personnes
# Out:
# /home/alexis/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,10,11,18,19,23,25,26,27,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (445684, 40)

# %%
persons = []
organizations = []

for i,d in df[243803:352491].iterrows():

    doc = nlp(d.message)

    if len(doc.ents) > 0:
        for ent in doc.ents:
            if ent.label_ == 'PERSON':
                persons.append(str(ent))
            elif ent.label_ == 'ORG':
                organizations.append(str(ent))

                
                
#             elif ent.label_ == 'GPE':
#                 GPE.append(str(ent))
#             elif ent.label_ == 'NORP':
#                 NORP.append(str(ent))
            # all the other entities that might make sense
#             elif (ent.label_ not in ['CARDINAL', 'ORDINAL', 'PERCENT','DATE','TIME']) :
#                 entities.append((str(ent), ent.label_))

# %%
print(sorted(list(set((persons)))))
# Out:
# [' ', '  ', '    Sack', '  Also', '  But', '  I. Cernovich', '  Love', '  Nuck', '  Romney', '  U N P O S S I', ' "', ' - Disdainus Maximus', ' A) soo', ' Absentee', ' And', ' And boy', ' Apple', ' Ba-da-ba-da-ba-be', ' Baron Trump', ' Brian', ' Cool', ' De Niro', ' Disdainus Maximus', ' Dylan Dylan Chapman', ' Fah', ' Fascism', ' Figuratively', ' Fuck', ' Gerson Eli', ' Gordon Ramsay', ' Gunnar Keller', ' Hell', ' Hillary Clinton', ' Hope', ' Le Penn', ' Like', ' Long', ' M-A-G-A "', ' Moore', ' Obama', ' Pence', ' Relentlessly', ' Richard', ' Sammy-BOY', ' Savage', ' Search', ' Starsha', ' Telling', ' The Emperor', ' They', ' Trump', ' Trump Tower', ' Yikes', ' You', ' Young Turks', ' Your dad', ' Zyklon', ' or', '! Hahahaha', '! Love', '#Savage', '#Trump #', '& Trump', '(Trump) in the nose', '-Karl Marx', '122mil', '125mil', '2kill', '4D Chess feat.', '4chan', '50', '6k', '6o-48 Trump', "70's/80", '7up', '8) Drain the Swamp in Washington  9) Prosecute Hillary', '80s Sylvester Silverstone', '8chan', '9/11" is', '9gag Kappa', '<3 Red', '= Cheek', '>', '> Paul Ryan', '>Bush', '>Marine', '>Paul Ryan', '>Trump', '@Summer Rey', '@cae Cai Evans', 'A. Cuck', 'A. Haddad', 'A. Lee', 'A. Wyatt Mann', 'A.J. Emerson', 'A1 Trump', 'AAntonia Rae', 'ABOUT', 'ABSOLUTE POWER', 'ACA', 'ACTION', 'AF1 B747-8', 'AGAINST Trump', 'AHAHAHAHAHAHAHA', 'AJ Becerra', 'AKA Hillary', 'AKIRA', 'ALL', 'ALTMAN', 'AMAZING', 'AMERICA', 'AMERICAN', 'ANGELA
abd EL Rahman Moaty', 'Abd El-Aziz Qaise', 'Abdallah Kandil', 'Abdel Amiri', 'Abdel Haram', 'Abdel Mohammed', 'Abdelhalim Abk El Bou', 'Abdullah Azhad', 'Abdullah Muhammad', 'Abdullah Safi', 'Abdullah Safi Thomas Ingwersen', 'Abe', 'Abe Foxman', 'Abe Lincoln', 'Abel', 'Abel Alvarado', 'Abelardo Rivera Levy', 'Abhilash Satpathy', 'Abhinav Prasad', 'Abi Ghosh', 'Abigail', 'Abigail Blaylock', 'Abigail Elli ...

# %%
print(sorted(list(set((organizations)))))
# Out:
# [' ', '  Bitch YOU', '  Fuck Hollywood', '  Means', '  Spis', '  a', ' >Freemason', ' Abree Williams', ' Allahu Akbar', ' Brain Force', ' Canada', ' Cause Palmela Geller', ' Championship Edition', ' Disdainus Maximus', ' Ground Zero', ' Happy Holidays', ' Healthcare', " Justice Department's", ' Marine Recon', ' New Hampshire', ' POST', ' Pizza Party', ' That', ' The New World Order', ' Time', ' W A', ' With', ' Yaeee General Radev', ' a', ' a FB', ' from Politico', ' the', '"Egg McMuffin"', '"Tea Party"', '#PizzaGate', '#Serbia', '#Trumpster', '&', "'High Energy'", '-152nd Microsoft Paint', '-55', '-LGBT Magazine', '-Meme War Veteran', '0,5', '0bama', '1 & 4', '1 Ice', '1,5', '10 Ana Mežnarić Moments', '101st Airborne Division', '104', '105th Armored Deplorables Light Division', '11/9 at Javits Center', '1ST Order of Business Comey', '1st Amendment', '1st Marine Division', '2 Books', '2 Pizza', '200k FB Fans', '25', '2AM', '2nd Amendment', '2nd Meme Division', '3.The Mellow Mushroom', '320kbps', '389th Serbian Volunteer Shitposting Brigade', '4-year', '40k', '44th', '4chan', "50's-60s American Cars", '500.000 Army & Border Guards', '50s', '6 Less Facebook', '60,839,922 & Trump', '60s', '62,972,226   ', '6th', '7,5% of', '7-Up, Tostitos', '7th Armored Meme Division', '7up', '9  ', '9/11', '9th Company"', ':D Wofür', '<', '<3 K U R I', '>', '>Alexander', '>CANADA', '>Triggered Student Fuck', '>White Nationalist', '@^&*', '@theis Oliver Oxholm Larsen', 'A Unique Autobiography', 'AAARRGH', 'AB', 'ABC', 'ABC CBS', 'ABC Colombia', 'ABDL', 'ABOARD', 'ABOUT', 'ABSOLUTELY', 'ACA', 'ACABEI DE COMPARTILHAR', 'ACP', 'ACT', 'ACT LIKE', 'ACTUALLY', 'ACTUALLY A TRAITOR', 'ADIOS', 'ADL', 'ADULTING', 'ADULTS', 'ADVANTAGE', 'AFAIC', 'AFD', 'AFK', 'AFL', 'AFTERSHOCK', 'AG', 'AGAIN', 'AGE', 'AGE OF SHITLORDS', 'AHAHAAHA', 'AHAHAH', 'AHAHAHAHAH', 'AHAHAHAHAHA', 'AHAHAHAHAHAHAH', 'AHAHAHAHAHAHAHAHAHAH', 'AHAHHA', 'AHAHHAAHHAAHAHAHA', 'AHEM', 'AHHAHAHAHAH DEZE POST', 'AHHAHAHAHAHAHAHA', 'AIDS', 'AIM', 'AIPAC', 'AJ', 'AJ Jackson Dylan Allred', 'AL IGUAL', 'ALA', 'ALAN', 'ALEX', 'ALIVE', 'ALL ON', 'ALL U.S. Military', 'ALMOST', 'ALOHA SNACKBAR', 'ALONE', 'ALOT', 'ALREADY', 'ALWAYS', 'AM', 'AM The Senate', 'AMEN', 'AMENDMENT', 'AMERICA AS SOON AS', 'AMERICAN', 'AMERICANS', 'AMMERRIICCAAAAA', 'ANF PLAY', 'ANIME', 'ANOTHER ENERGY POST GOD EMPEROR', 'ANSCHLUSS', 'ANTI', 'ANTIFA', 'ANYBODY', 'ANYONE', 'ANYTHING', 'ANYWAYS', 'ANYWHERE', 'ANZAC', 'AOL Time Warner', 'AP', 'APA', 'APC', 'APOLOGIZE', 'AR', 'AR-35S', 'ARRESTED', 'ARRRGH', 'AS', 'ASAP', 'ASK', 'ASS ON OR', 'ASSHOLE', 'ATAK', 'AUHSAUSHAUHS', 'AUTISM', 'AVE', 'AVGN', 'AWESOME', 'AWFUL', 'AWOL', 'AYYYY', 'Aaaand', 'Aarón VM Jose', 'Abbott', 'Abhishek Burman', 'Abhishek Ronak Sehaam Layla', 'Abrahamic', 'Abreuve', 'Abril Paola Martinez', 'Abuela', 'Access Hollywood', 'Acknowledge', 'Acute', 'Adam &eve', 'AdamBicanic', 'Addio', 'Addison Aaron', 'Addison J Grace', 'Adem Perezic', 'Adin Ghosh', 'Adin Ghosh Gerad', 'Adin Ghosh Tason Umad', 'Adios', 'Aditya Bajekal Azarelle Shobi', 'Aditya Bajekal Azarelle Shobi Naidu', 'Aditya Bhattacharya', 'Aditya Ganguly', 'Admin', 'Administration', 'Adolph Hitler', 'Adriano Ciotto Luccas', 'Adrianus de Ithaca', 'Adrien Lecostaud Lirola', 'Adult Baby Diaper Lover', 'Advanced', 'Advanced Shitposting Pants', 'Advisory Committee', 'Aedan Joseph Brown', 'Aemil Kunal Lube', 'Aemil Palm Cockatoo', 'Aemil Palm Kunal Chawla', 'Aemil Palm Kunal Chawla Dead', 'Aemil Palm Liberal', 'Aerik Daagennfield Perfect', 'Aether Revolt', 'Affirmative', "Afro'd", 'Agassi Tomeldan', 'Agathe Mathis Leave Pepe Alone', 'Age of Enlightenment', 'Ahahah', 'Ahahahahah Claudio Almasio', 'AhahahahahAndrea Trevisi', 'Ahanaf MD Niloy', 'Ahhahaha', 'Ahhahahah Kaneshka Shafie', 'Ahhhh', 'Ahmet', 'Aidan Flame', 'Aidan Harley Kieran', 'Aidan Leeming Luke', 'Aids Skrillex', 'Aikido', 'Ailemenshirne77@yahoo.com', 'Air Canada', 'Aishah Shekhani xD', 'Akash Yadav Shanmukh Singh', 'Akhil Bansal Nope', 'Al-qaed ...
