# %%
#pandas est une  Data Analysis Library: ------> https://pandas.pydata.org/
#on nome pandas comme pd pour agilizer l'histoire
import pandas as pd

DATA_PATH = './'
filename  = 'fbget_sample_05.csv'

df = pd.read_csv(DATA_PATH + filename)

print("\nLe corpus contient {} rows et {} colonne(s)".format(df.shape[0], df.shape[1]))
# Out:
# Le corpus contient 6698 rows et 14 colonne(s)

# %%
#enlever des rows(de 0 a 1000)
print("avant: {}".format(df.shape))
df = df[0:1000]

print("apres: {}".format(df.shape))
# Out:
# avant: (100, 15)
# apres: (100, 15)

# %%
df
# Out:
#                               post_id parent_id  \
# 0     791373644322801_804647722995393       NaN
# 1   791373644322801_10208395558143809       NaN
# 2   791373644322801_10208395558143809       NaN
# 3     791373644322801_826082107518621       NaN
# 4     791373644322801_825876004205898       NaN
# 5     791373644322801_825877150872450       NaN
# 6     791373644322801_825875487539283       NaN
# 7     791373644322801_825897464203752       NaN
# 8     791373644322801_825291584264340       NaN
# 9     791373644322801_822608651199300       NaN
# 10    791373644322801_822274057899426       NaN
# 11    791373644322801_819943248132507       NaN
# 12    791373644322801_819371854856313       NaN
# 13    791373644322801_870304516429713       NaN
# 14    791373644322801_869942673132564       NaN
# 15    791373644322801_869953173131514       NaN
# 16    791373644322801_869928933133938       NaN
# 17    791373644322801_869928933133938       NaN
# 18    791373644322801_869928933133938       NaN
# 19    791373644322801_869928933133938       NaN
# 20    791373644322801_869928933133938       NaN
# 21    791373644322801_869760256484139       NaN
# 22    791373644322801_869658173161014       NaN
# 23    791373644322801_869658173161014       NaN
# 24    791373644322801_869658173161014       NaN
# 25    791373644322801_869658173161014       NaN
# 26    791373644322801_869658173161014       NaN
# 27    791373644322801_869658173161014       NaN
# 28    791373644322801_868693219924176       NaN
# 29    791373644322801_868689793257852       NaN
# ..                                ...       ...
# 70    791373644322801_860817914045040       NaN
# 71    791373644322801_860297054097126       NaN
# 72    791373644322801_860297054097126       NaN
# 73    791373644322801_860320220761476       NaN
# 74    791373644322801_860118687448296       NaN
# 75    791373644322801_859379457522219       NaN
# 76    791373644322801_859379457522219       NaN
# 77    791373644322801_858961574230674       NaN
# 78    791373644322801_858961574230674       NaN
# 79    791373644322801_858961574230674       NaN
# 80    791373644322801_858663804260451       NaN
# 81    791373644322801_858663804260451       NaN
# 82    791373644322801_858673147592850       NaN
# 83    791373644322801_858673147592850       NaN
# 84    791373644322801_858678787592286       NaN
# 85    791373644322801_858666094260222       NaN
# 86    791373644322801_858666094260222       NaN
# 87    791373644322801_858666094260222       NaN
# 88    791373644322801_858666094260222       NaN
# 89    791373644322801_858666094260222       NaN
# 90    791373644322801_858666094260222       NaN
# 91    791373644322801_858666094260222       NaN
# 92    791373644322801_858666094260222       NaN
# 93    791373644322801_858666094260222       NaN
# 94    791373644322801_858666094260222       NaN
# 95    791373644322801_858666094260222       NaN
# 96    791373644322801_858666094260222       NaN
# 97    791373644322801_858666094260222       NaN
# 98    791373644322801_858666094260222       NaN
# 99    791373644322801_858666094260222       NaN
#
#                              comment_id                                cc_id  \
# 0       804647722995393_804670119659820                                  NaN
# 96          0.0            0.0  2016-06-10 15:55:12    858666094260222
# 97          0.0            0.0  2016-05-13 14:12:05    858666094260222
# 98          0.0            0.0  2016-10-23 14:34:09    858666094260222
# 99          0.0            0.0  2016-08-09 03:50:57    858666094260222
#
#     log_klout                                      message_clean  \
# 0         1.0  crumb bum A term of utter contempt for a worth...
# 1         1.0  Im english so i cant vote but my wife is a new...
# 2         1.0  He also can t be bought off dont toe the repub...
# 3         0.0  ATTENTION EVERYONE Early voters have reported ...
# 4         0.0  ATTENTION EVERYONE Early voters have reported ...
# 5         0.0  ATTENTION EVERYONE Early voters have reported ...
# 6         0.0  ATTENTION EVERYONE Early voters have reported ...
# 7         0.0  ATTENTION EVERYONE Early voters have reported ...
# 8         0.0  ATTENTION EVERYONE Early voters have reported ...
# 9         1.0  Jeb What is that stance And that slogan Trump ...
# 10        1.0  That s not a viable torture method Not only do...
# 11        0.0  Let s dispel once and for all with this fictio...
# 12        4.0  Facebook is attempting to hide the truth by fl...
# 13        0.0  It was a nice idea and song the only problem w...
# 14        2.0  Why Mr Anderson Why why Why do you do it Why w...
# 15        1.0  We shall be his finest warriors we that have g...
# 16        3.0  Ha hope you know the Nazis weren t Socialist T...
# 17        3.0  inb4 Nationalism in Germany wasn t even remote...
# 18        1.0  Hitler was a National Socialist And Mussolini ...
# 19        0.0  Our forefathers fought against socialists and ...
# 20        0.0  No freedom and nothing else is socialism socia...
# 21        4.0  Gonna be honest I literally thought it was a p...
# 22        1.0  Basketball ring tells you everything Do you re...
# 23        1.0  Good politician That s something Isn t the who...
# 24        0.0  OJ Lopez obama was not a good president By pol...
# 25        1.0  All of Teds policy have mirrored Trumps Are th...
# 26        0.0  OJ Lopez oh come on are you serious trump s po...
# 27        1.0  Not a Cruz fan But constantly shills for Cruz ...
# 28        0.0  Trump is typically the God Emperor in these pi...
# 29        1.0  Mark Menegus I ve been to several 3rd world co...
# ..        ...                                                ...
# 70        1.0  Don t be down on George he saw freedoms being ...
# 71        1.0  I have a feeling Bernie s Presidency will invo...
# 72        1.0  Yeah because if his father had given him a who...
# 73        1.0  So Zach you support an old establishment senat...
# 74        2.0  The culture clash began to approach a climax l...
# 75        1.0  Many of my officer friends got out after doing...
# 76        0.0  I do wish you the best of luck but be aware if...
# 77        3.0  Joe McCarthy was absolutely right about everyt...
# 78        1.0  Yes let s just kowtow to the liberals agenda a...
# 79        0.0  Im gonna vote for someone that has barely any ...
# 80        0.0  It s making it out to be something it s not it...
# 81        0.0  Voted to dump Vermont s nuclear waste in a maj...
# 82        2.0  Back when Teddy Roosevelt ran the party elites...
# 83        0.0  A must read By Mark Osterloh MD JD RPh 7 hrs D...
# 84        0.0  Back when Teddy Roosevelt ran the party elites...
# 85        3.0  Erik Rivas as a US Marine with 2 tours in Afgh...
# 86        0.0  Rob Espinoza what these dirty corrupt wars did...
# 87        3.0  And the police here are hired henchmen probabl...
# 88        0.0  Mike Swierk I feel the same way Those young Me...
# 89        0.0  Elisabeth Barker I agree But I think the crowd...
# 90        1.0  Share This Help America Democrats have hillary...
# 91        2.0  DICK MORRIS FORMER POLITICAL ADVISOR TO PRESID...
# 92        1.0  You have no respect fir our military Clinton T...
# 93        3.0  You can t just go to a speech and continue on ...
# 94        1.0  What is it that she lied about Conservatives a...
# 95        0.0  How thick headed those people are They have th...
# 96        0.0  Clinton supporters are incapable of seeing hea...
# 97        0.0  I find this typical of Clintons to NEVER answe...
# 98        0.0  Well having watched the video I will say it wa...
# 99        0.0  So sick some of those people who don t listen ...
#
#                                            tokens_all
# 0   [crumb, bum, a, term, of, utter, contempt, for...
# 1   [im, english, so, i, cant, vote, but, my, wife...
# 2   [he, also, can, t, be, bought, off, dont, toe,...
# 3   [attention, everyone, early, voters, have, rep...
# 4   [attention, everyone, early, voters, have, rep...
# 5   [attention, everyone, early, voters, have, rep...
# 6   [attention, everyone, early, voters, have, rep...
# 7   [attention, everyone, early, voters, have, rep...
# 8   [attention, everyone, early, voters, have, rep...
# 9   [jeb, what, is, that, stance, and, that, sloga...
# 10  [that, s, not, a, viable, torture, method, not...
# 11  [let, s, dispel, once, and, for, all, with, th...
# 12  [facebook, is, attempting, to, hide, the, trut...
# 13  [it, was, a, nice, idea, and, song, the, only,...
# 14  [why, mr, anderson, why, why, why, do, you, do...
# 15  [we, shall, be, his, finest, warriors, we, tha...
# 16  [ha, hope, you, know, the, nazis, weren, t, so...
# 17  [inb4, nationalism, in, germany, wasn, t, even...
# 18  [hitler, was, a, national, socialist, and, mus...
# 19  [our, forefathers, fought, against, socialists...
# 20  [no, freedom, and, nothing, else, is, socialis...
# 21  [gon, na, be, honest, i, literally, thought, i...
# 22  [basketball, ring, tells, you, everything, do,...
# 23  [good, politician, that, s, something, isn, t,...
# 24  [oj, lopez, obama, was, not, a, good, presiden...
# 25  [all, of, teds, policy, have, mirrored, trumps...
# 26  [oj, lopez, oh, come, on, are, you, serious, t...
# 27  [not, a, cruz, fan, but, constantly, shills, f...
# 28  [trump, is, typically, the, god, emperor, in, ...
# 29  [mark, menegus, i, ve, been, to, several, 3rd,...
# ..                                                ...
# 70  [don, t, be, down, on, george, he, saw, freedo...
# 71  [i, have, a, feeling, bernie, s, presidency, w...
# 72  [yeah, because, if, his, father, had, given, h...
# 73  [so, zach, you, support, an, old, establishmen...
# 74  [the, culture, clash, began, to, approach, a, ...
# 75  [many, of, my, officer, friends, got, out, aft...
# 76  [i, do, wish, you, the, best, of, luck, but, b...
# 77  [joe, mccarthy, was, absolutely, right, about,...
# 78  [yes, let, s, just, kowtow, to, the, liberals,...
# 79  [im, gon, na, vote, for, someone, that, has, b...
# 80  [it, s, making, it, out, to, be, something, it...
# 81  [voted, to, dump, vermont, s, nuclear, waste, ...
# 82  [back, when, teddy, roosevelt, ran, the, party...
# 83  [a, must, read, by, mark, osterloh, md, jd, rp...
# 84  [back, when, teddy, roosevelt, ran, the, party...
# 85  [erik, rivas, as, a, us, marine, with, 2, tour...
# 86  [rob, espinoza, what, these, dirty, corrupt, w...
# 87  [and, the, police, here, are, hired, henchmen,...
# 88  [mike, swierk, i, feel, the, same, way, those,...
# 89  [elisabeth, barker, i, agree, but, i, think, t...
# 90  [share, this, help, america, democrats, have, ...
# 91  [dick, morris, former, political, advisor, to,...
# 92  [you, have, no, respect, fir, our, military, c...
# 93  [you, can, t, just, go, to, a, speech, and, co...
# 94  [what, is, it, that, she, lied, about, conserv...
# 95  [how, thick, headed, those, people, are, they,...
# 96  [clinton, supporters, are, incapable, of, seei...
# 97  [i, find, this, typical, of, clintons, to, nev...
# 98  [well, having, watched, the, video, i, will, s...
# 99  [so, sick, some, of, those, people, who, don, ...
#
# [100 rows x 15 columns]

# %%
cleancom = df.message_clean

# %%
#Il faut mtn tokenizer,virer la ponctuation, et enlever les mots inutiles a l'analise

#1 Tokenization<----
from nltk import word_tokenize


df['tokens_all']  = df.message_clean.apply(
    lambda r : word_tokenize(str(r).lower())
)


print(df.tokens_all.head)
#tokens_on_space = sentence.split(' ')
#print(tokens_on_space)
# Out:
# <bound method NDFrame.head of 0     [crumb, bum, a, term, of, utter, contempt, for...
# 1     [im, english, so, i, cant, vote, but, my, wife...
# 2     [he, also, can, t, be, bought, off, dont, toe,...
# 3     [attention, everyone, early, voters, have, rep...
# 4     [attention, everyone, early, voters, have, rep...
# 5     [attention, everyone, early, voters, have, rep...
# 6     [attention, everyone, early, voters, have, rep...
# 7     [attention, everyone, early, voters, have, rep...
# 8     [attention, everyone, early, voters, have, rep...
# 9     [jeb, what, is, that, stance, and, that, sloga...
# 10    [that, s, not, a, viable, torture, method, not...
# 11    [let, s, dispel, once, and, for, all, with, th...
# 12    [facebook, is, attempting, to, hide, the, trut...
# 13    [it, was, a, nice, idea, and, song, the, only,...
# 14    [why, mr, anderson, why, why, why, do, you, do...
# 15    [we, shall, be, his, finest, warriors, we, tha...
# 16    [ha, hope, you, know, the, nazis, weren, t, so...
# 17    [inb4, nationalism, in, germany, wasn, t, even...
# 18    [hitler, was, a, national, socialist, and, mus...
# 19    [our, forefathers, fought, against, socialists...
# 20    [no, freedom, and, nothing, else, is, socialis...
# 21    [gon, na, be, honest, i, literally, thought, i...
# 22    [basketball, ring, tells, you, everything, do,...
# 23    [good, politician, that, s, something, isn, t,...
# 24    [oj, lopez, obama, was, not, a, good, presiden...
# 25    [all, of, teds, policy, have, mirrored, trumps...
# 26    [oj, lopez, oh, come, on, are, you, serious, t...
# 27    [not, a, cruz, fan, but, constantly, shills, f...
# 28    [trump, is, typically, the, god, emperor, in, ...
# 29    [mark, menegus, i, ve, been, to, several, 3rd,...
#                             ...
# 70    [don, t, be, down, on, george, he, saw, freedo...
# 71    [i, have, a, feeling, bernie, s, presidency, w...
# 72    [yeah, because, if, his, father, had, given, h...
# 73    [so, zach, you, support, an, old, establishmen...
# 74    [the, culture, clash, began, to, approach, a, ...
# 75    [many, of, my, officer, friends, got, out, aft...
# 76    [i, do, wish, you, the, best, of, luck, but, b...
# 77    [joe, mccarthy, was, absolutely, right, about,...
# 78    [yes, let, s, just, kowtow, to, the, liberals,...
# 79    [im, gon, na, vote, for, someone, that, has, b...
# 80    [it, s, making, it, out, to, be, something, it...
# 81    [voted, to, dump, vermont, s, nuclear, waste, ...
# 82    [back, when, teddy, roosevelt, ran, the, party...
# 83    [a, must, read, by, mark, osterloh, md, jd, rp...
# 84    [back, when, teddy, roosevelt, ran, the, party...
# 85    [erik, rivas, as, a, us, marine, with, 2, tour...
# 86    [rob, espinoza, what, these, dirty, corrupt, w...
# 87    [and, the, police, here, are, hired, henchmen,...
# 88    [mike, swierk, i, feel, the, same, way, those,...
# 89    [elisabeth, barker, i, agree, but, i, think, t...
# 90    [share, this, help, america, democrats, have, ...
# 91    [dick, morris, former, political, advisor, to,...
# 92    [you, have, no, respect, fir, our, military, c...
# 93    [you, can, t, just, go, to, a, speech, and, co...
# 94    [what, is, it, that, she, lied, about, conserv...
# 95    [how, thick, headed, those, people, are, they,...
# 96    [clinton, supporters, are, incapable, of, seei...
# 97    [i, find, this, typical, of, clintons, to, nev...
# 98    [well, having, watched, the, video, i, will, s...
# 99    [so, sick, some, of, those, people, who, don, ...
# Name: tokens_all, Length: 100, dtype: object>

# %%
# remove stopwords

def remove_stopword(tokens):
     return [w for w in tokens if (w not in list_stopwords) ]

# Verifier que ca marche
remove_stopword(tokens)

# appliquer a la dataframe

df['tokens'] = df.tokens_all.apply(
    lambda tks : remove_stopword(tks) 
)

print (df.tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2e435ad12680> in <module>()
#       5
#       6 # Verifier que ca marche
# ----> 7 remove_stopword(tokens)
#       8
#       9 # appliquer a la dataframe
#
# NameError: name 'tokens' is not defined

# %%
df_textm = df[['tokens']]
df_textm

# %%
# nombre de tokens par rangée
pd.options.mode.chained_assignment = None
df['token_count'] = df.tokens.apply( lambda r : len(r) )

print(df_textm.head())

# %%
# repartition du nombre de tokens
df.token_count.describe()

# %%
# # L'operateur de translation
translator = str.maketrans(dict_ponctuation)

new_sentence = sentence.translate(translator)
print(sentence)
print(new_sentence)

# %%
#3 stopwords <----
tokens = word_tokenize(new_sentence)
print(tokens)

from nltk.corpus import stopwords


# print("=== stopwords - français:")
# print(sorted(stopwords.words('french')))

list_stopwords = stopwords.words('french') + ['les', 'de']

# # equivalent:
# stopwords = stopwords.words('french')
# stopwords.append('les')
# stopwords.append('de')


# alternative
#from stop_words import get_stop_words
#list_stopwords = get_stop_words(‘en’)
# 
tokens_sans_stopwords = [w for w in tokens if (w not in list_stopwords) ]

## Equivalent 
tokens_sans_stopwords = []
for w in tokens:
    if w not in list_stopwords:
        tokens_sans_stopwords.append(w)



print(tokens_sans_stopwords)

# %%
# MTN on refqit mqis qvec le  CORPUS "est....rep" c'st donc bien de essayer dans les petite frases le coe avant de apliquer a tout le corpus
# Enlevons la ponctuation

df['text_no_punctuation'] = df.text.apply(lambda 
    r : ( r.translate(translator) ) 
)
df.head()

# %%
# Tokenizer

df['tokens_all']  = df.text_no_punctuation.apply(
    lambda r : word_tokenize(r.lower())
)

df.head()

# %%
# remove stopwords

def remove_stopword(tokens):
     return [w for w in tokens if (w not in list_stopwords) ]

# Verifier que ca marche
remove_stopword(tokens)

# appliquer a la dataframe

df['tokens'] = df.tokens_all.apply(
    lambda tks : remove_stopword(tks) 
)

df.head()

# %%
# enlever les colonnes intermediaires

print(df.columns)

df = df[['text', 'tokens']]

print(df.columns)

# %%
# nombre de tokens par rangée
pd.options.mode.chained_assignment = None
df['token_count'] = df.tokens.apply( lambda r : len(r) )

print(df.head())

# repartition du nombre de tokens
df.token_count.describe()

#count est egale aux element, faire attention car on peur se tronmper!!!!!
# les reste des donnes sont en relation a la distrubution des tokens par raport aux lignes, sa distribution a partir de la mediane, a.k.a. on travaille avec la variabilité

# %%
# On voit que AU MOINS un document a 955 token, il faut le cherche. On veut savoir les valeurs extremes car on se trouve dans des tecniques de analyse base tus la distribution normale. 
#Pour les apliquer il nous faut idealement une distrubution normale---> este vergueo es como las rgresiones, qedemos "distribucion normale, pero al final a la mara le pela el niessss

condition = (df.token_count == 955)
print(df[condition].text.values)

# %%
#de maniere exploratire on veut voir les cas extremes
# quel index
print(df[condition].index)

# 
condition = (df.token_count > 500)
print(df[condition].shape)
condition1 = (df.token_count > 400)
print(df[condition1].shape)
condition2 = (df.token_count > 300)
print(df[condition2].shape)
condition3 = (df.token_count > 200)
print(df[condition3].shape)
condition4 = (df.token_count > 100)
print(df[condition4].shape)

# %%
# enlever le paragraphe le plus long

condition_filtrage = df.token_count < 955
print(df[condition_filtrage].shape)

df = df[condition_filtrage]
print(df[condition_filtrage].shape)

print(df.token_count.describe())

# %%
# Gensim - Vocabulaire

from gensim import corpora, models
dictionary  = corpora.Dictionary(df.tokens)
print(dictionary)

# %%
# corpus_gensim

df['corpus_gensim'] = df.tokens.apply(lambda d : dictionary.doc2bow(d))

print(df['corpus_gensim'] .head().values)

# %%
# aggreger les rows
corpus_gensim = [c for c in df.corpus_gensim ]

# %%
num_topics= 40

# Le model LDA
lda = models.LdaModel(corpus_gensim,
    id2word      = dictionary,
    num_topics   = num_topics,
    alpha        = 'asymmetric',
    eta          = 'auto',
    passes       = 2,
    iterations   = 20
)

# %%
for t in lda.show_topics(num_topics=num_topics, formatted=True, log = False):
    print("\n=== topic #{}".format(t[0]))
    print(t[1].replace('*', ': ').replace(' +',', ').replace('"',''))

# %%
num_topics= 60

# Le model LDA
lda = models.LdaModel(corpus_gensim,
    id2word      = dictionary,
    num_topics   = num_topics,
    alpha        = 'asymmetric',
    eta          = 'auto',
    passes       = 2,
    iterations   = 20
)

for t in lda.show_topics(num_topics=num_topics, formatted=True, log = False):
    print("\n=== topic #{}".format(t[0]))
    print(t[1].replace('*', ': ').replace(' +',', ').replace('"',''))

# %%
num_topics= 25

# Le model LDA
lda = models.LdaModel(corpus_gensim,
    id2word      = dictionary,
    num_topics   = num_topics,
    alpha        = 'asymmetric',
    eta          = 'auto',
    passes       = 3,
    iterations   = 40
)

for t in lda.show_topics(num_topics=num_topics, formatted=True, log = False):
    print("\n=== topic #{}".format(t[0]))
    print(t[1].replace('*', ': ').replace(' +',', ').replace('"',''))

# %%
#pour resumer, on agite la baguete magique, on teste le nombre de topics, le nombre de iteration et le nombre de passes jusqu'a 
#trouver un vomit de topic minimement interpretable pour mettre des mot savant tel que "attentint la stabilité", 
#"apres une selection exhaustive" qui veut dire que on sait pas pourquoi mais on se la pete de ecrire deux ligne de code
